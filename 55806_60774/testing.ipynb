# %%
###############################################################################
## Computer Vision 2025-2026 - NOVA FCT
## Assignment 1
##
## Student 1
## Goncalo Gomes 60774
##
###############################################################################
import cv2
import cv2 as cv
import numpy as np
import os
import glob
import json
from matplotlib import pyplot as plt

# SECTION 3: IMAGE PREPROCESSING
"""
    s all images from input directory and resize them maintaining aspect ratio.
    Smaller side 512 pixels.

    Returns:
        list: List of tuples (filename, resized_image)
    """
def load_and_resize_images(input_dir):

    # Get all image files sorted
    image_paths = sorted(glob.glob(os.path.join(input_dir, "*.*")))

    resized_images = []

    for img_path in image_paths:

        if not img_path.lower().endswith(('.png', '.jpg', '.jpeg')):
            continue

        img = cv.imread(img_path)
        if img is None:
            continue

        # Get image dimensions
        h, w = img.shape[:2]

        # Calculate new dimensions
        if h < w:
            new_h = 512
            new_w = int(w * 512 / h)
        else:
            new_w = 512
            new_h = int(h * 512 / w)

        # Resize image
        resized = cv.resize(img, (new_w, new_h), interpolation=cv.INTER_AREA)

        # Store filename and resized image
        filename = os.path.basename(img_path)
        resized_images.append((filename, resized))

        print(f"Loaded and resized: {filename} ({w}x{h} -> {new_w}x{new_h})")

    return resized_images

# SECTION 4: HISTOGRAM SIMILARITY
    """
    calculate normalized color histogram for an image.

    Args:
        image: BGR image

    Returns:
        Normalized histogram
    """
def calculate_histogram(image):

    # Define histogram parameters
    # Using 8 bins per channel
    hist_size = [8, 8, 8]
    ranges = [0, 256, 0, 256, 0, 256]  # RGB ranges

    # Compute 3D histogram
    hist = cv.calcHist([image], [0, 1, 2], None, hist_size, ranges)

    # Normalize histogram
    hist = cv.normalize(hist, hist).flatten()

    return hist

"""
    Calculate distance between two histograms.
    Lower values = more similar images.

    Args:
        hist1: First histogram
        hist2: Second histogram

    Returns:
        float: Distance value
    """
def histogram_distance(hist1, hist2, option):
    if option == "btc":
        # Bhattacharyya distance
        return cv.compareHist(hist1, hist2, cv.HISTCMP_BHATTACHARYYA)
    if option == "chi":
        # Chi-Square distance
        return cv.compareHist(hist1, hist2, cv.HISTCMP_CHISQR)
    if option == "my_chi":
        # Custom Chi-Square implementation
        return my_chi_square(hist1, hist2)
    raise Exception("Invalid algorythm parameter")
def find_similar_groups(resized_images, selection, threshold=0.3):
    """
    Group similar images based on histogram comparison.
    Assumes images are in chronological order.

    Args:
        resized_images: List of (filename, image) tuples
        threshold: Similarity threshold (lower = more strict)

    Returns:
        list: List of groups, each group is a list of (filename, image) tuples
    """
    if len(resized_images) == 0:
        return []

    groups = []
    current_group = [resized_images[0]]

    # Compute histogram for first image
    prev_hist = calculate_histogram (resized_images[0][1])

    for i in range(1, len(resized_images)):
        filename, image = resized_images[i]
        curr_hist = calculate_histogram(image)

        # Compare with previous image
        dist = histogram_distance(prev_hist, curr_hist, selection)

        # print(dist)
        print(f"Distance between image {resized_images[i-1][0]} and image {filename}: {dist:.4f}")

        if dist < threshold:
            # Similar to previous image we add
            current_group.append((filename, image))
        else:
            # Different from previous - also check if current group is bigger that 2
            if len(current_group) >= 3:  # More than 2 similar images we add
                groups.append(current_group)
            # Start new group
            current_group = [(filename, image)]

        prev_hist = curr_hist

    # Last group
    if len(current_group) >= 3:
        groups.append(current_group)

    return groups

    """
    Save similar image groups to separate folders.

    Args:
        groups: List of image groups
        output_dir: Output directory path
    """
def save_similar_groups(groups, output_dir):

    for id , group in enumerate(groups):
        # Creates folder for this group
        folder_name = f"similar-{id }"
        folder_path = os.path.join(output_dir, folder_name)
        os.makedirs(folder_path, exist_ok=True) #Checks if exists also

        # Save all images in the group
        for filename, image in group:
            output_path = os.path.join(folder_path, filename)
            cv.imwrite(output_path, image)

        print(f"Created {folder_name} with {len(group)} images")

# SECTION 5: HISTOGRAM ANALYSIS AND WHITE BALANCE
"""
    Compute average histogram for a group of images
    Args:
        group: List of (filename, image) tuples
    Returns:
        Average histogram
    """
def compute_average_histogram(group):

    histograms = [calculate_histogram(img) for _, img in group]
    avg_hist = np.mean(histograms, axis=0)
    return avg_hist

"""
    Apply white balance to image based on target average RGB values.
    Args:
        image: Input BGR image
        target_avg: Target average RGB values
    Returns:
        White-balanced image
    """
def apply_white_balance(image, target_avg):

    # Calculate current average for each channel
    current_avg = np.mean(image, axis=(0, 1))  # [B, G, R]

    # Calculate scaling factors for each channel
    scales = np.where(current_avg > 0, target_avg / current_avg, 1.0)

    # Apply scaling
    balanced = image.astype(np.float32)
    for i in range(3):
        balanced[:, :, i] = balanced[:, :, i] * scales[i]

    # Clip values
    balanced = np.clip(balanced, 0, 255).astype(np.uint8)

    return balanced

"""
    Save histogram visualization for a group.
    Args:
        group: List of (filename, image) tuples
        folder_path: Path to save the histogram image
    """
def save_histogram_visualization(group, folder_path):

    try:
        import matplotlib
        matplotlib.use('Agg')
        import matplotlib.pyplot as plt
    except ImportError:
        print(f"Warning: matplotlib not available. Skipping histogram visualization.")
        return


    all_histograms = {'R': [], 'G': [], 'B': []}

    for filename, image in group:
        # OpenCV uses BGR, swap to RGB
        img_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)
        R, G, B = img_rgb[:,:,0], img_rgb[:,:,1], img_rgb[:,:,2]

        # Get histograms - simple bincount like the example
        hist_r = np.bincount(R.ravel(), minlength=256)
        hist_g = np.bincount(G.ravel(), minlength=256)
        hist_b = np.bincount(B.ravel(), minlength=256)

        all_histograms['R'].append(hist_r)
        all_histograms['G'].append(hist_g)
        all_histograms['B'].append(hist_b)

    # Calculate average histograms
    avg_histograms = {
        'R': np.mean(all_histograms['R'], axis=0),
        'G': np.mean(all_histograms['G'], axis=0),
        'B': np.mean(all_histograms['B'], axis=0)
    }

    bins = np.arange(256)

    # Create figure with subplots one for each image + one for average
    num_images = len(group)

    # If few images, show individual + average. Otherwise just show average
    if num_images <= 5:
        # images individually + average
        fig, axes = plt.subplots(2, 3, figsize=(18, 10))
        axes = axes.flatten()

        # individual images
        for i, (filename, _) in enumerate(group[:5]):  # Max 5 individual
            ax = axes[i]
            ax.bar(bins, all_histograms['R'][i], color='red', alpha=0.4, label='Red')
            ax.bar(bins, all_histograms['G'][i], color='green', alpha=0.4, label='Green')
            ax.bar(bins, all_histograms['B'][i], color='blue', alpha=0.4, label='Blue')
            ax.set_title(filename, fontsize=10)
            ax.set_xlabel('Pixel Value')
            ax.set_ylabel('Frequency')
            ax.legend(fontsize=8)
            ax.grid(True, alpha=0.3, axis='y')

        # Plot average in the last subplot
        ax = axes[5]
        ax.bar(bins, avg_histograms['R'], color='red', alpha=0.4, label='Red')
        ax.bar(bins, avg_histograms['G'], color='green', alpha=0.4, label='Green')
        ax.bar(bins, avg_histograms['B'], color='blue', alpha=0.4, label='Blue')
        ax.set_title('AVERAGE', fontsize=10, fontweight='bold')
        ax.set_xlabel('Pixel Value')
        ax.set_ylabel('Frequency')
        ax.legend(fontsize=8)
        ax.grid(True, alpha=0.3, axis='y')

        plt.suptitle(f'RGB Histograms - All {num_images} Images', fontsize=14, fontweight='bold')
    else:
        # show the average for many images
        fig, ax = plt.subplots(figsize=(10, 5))
        ax.bar(bins, avg_histograms['R'], color='red', alpha=0.4, label='Red')
        ax.bar(bins, avg_histograms['G'], color='green', alpha=0.4, label='Green')
        ax.bar(bins, avg_histograms['B'], color='blue', alpha=0.4, label='Blue')
        ax.set_title(f'RGB Histogram - Average of {num_images} Images', fontsize=14, fontweight='bold')
        ax.set_xlabel('Pixel Value', fontsize=11)
        ax.set_ylabel('Frequency', fontsize=11)
        ax.legend(fontsize=10)
        ax.grid(True, alpha=0.3, axis='y')

    plt.tight_layout()

    # Save the figure
    output_path = os.path.join(folder_path, 'histograms.jpg')
    plt.savefig(output_path, dpi=120, bbox_inches='tight')
    plt.close(fig)

    print(f"  Saved histogram visualization: {output_path}")

    """
    Process each similar-# folder:
    - Compute average histogram
    - Apply white balance
    - Save histogram visualization
    """
def process_similar_folders(output_dir):

    similar_folders = sorted([f for f in os.listdir(output_dir)
                             if f.startswith('similar-')])

    for folder_name in similar_folders:
        folder_path = os.path.join(output_dir, folder_name)

        # Load all images from this folder
        image_files = sorted(glob.glob(os.path.join(folder_path, "*.jpg")))
        # Filter out histogram
        image_files = [f for f in image_files
                      if 'histogram' not in os.path.basename(f).lower()
                      and 'equal' not in os.path.basename(f).lower()]

        group = []
        original_group = []

        for img_path in image_files:
            img = cv.imread(img_path)
            if img is not None:
                filename = os.path.basename(img_path)
                original_group.append((filename, img.copy()))
                group.append((filename, img))

        if len(group) == 0:
            continue

        print(f"\nProcessing {folder_name}...")
        print(f"  Found {len(group)} images ")

        # Calculate average color (before white balance) for statistics
        avg_colors = [np.mean(img, axis=(0, 1)) for _, img in original_group]
        avg_color = np.mean(avg_colors, axis=0)  # [B, G, R]
        avg_color_rgb = [int(avg_color[2]), int(avg_color[1]), int(avg_color[0])]  # Convert to RGB

        print(f"  Average color (RGB): {avg_color_rgb}")

        # Compute average histogram from original images
        avg_hist = compute_average_histogram(original_group)

        # Calculate target average color for white balance
        # Use the average from all images in the group
        target_avg = avg_color  # [B, G, R]

        # Apply white balance to all images and save
        print(f"  Applying white balance to {len(group)} images...")
        for filename, image in group:
            # Apply white balance
            balanced = apply_white_balance(image, target_avg)

            # Save white-balanced image
            output_path = os.path.join(folder_path, filename)
            cv.imwrite(output_path, balanced)

        # Save histogram visualization (before white balance)
        save_histogram_visualization(original_group, folder_path)

        print(f" {folder_name} processed successfully")
# SECTION 6: MOPS DESCRIPTOR
def my_track_points(img):
    features = cv2.goodFeaturesToTrack(img)
    return

# %%
def my_chi_square(hist1, hist2):
    # print("MY CHI-SQUARE")
    # print(hist1)

    non_zero = 1e-11

    hist_array1 = np.asarray(hist1)
    hist_array2 = np.asarray(hist2)

    # chi_square = 0.5 * np.sum( ((hist1 - hist2) ** 2) / (hist1 + hist2 + non_zero))
    chi_square = 0.5 * np.sum([((a - b) ** 2 ) / (a + b + non_zero)
                               for (a,b) in zip(hist_array1, hist_array2)])
    # print(f"CHI_SQAURE = {chi_square}")
    return chi_square

# %%
def my_track_points(img, max_corners, threshold, mindist):
    features = cv2.goodFeaturesToTrack(img, maxCorners=max_corners, qualityLevel=threshold, minDistance=mindist)
    print(features)
    return features

def my_point_rotation(img, window_size=8, kernel_size=3):
    sobel_x = cv2.Sobel(img, cv2.CV_64F, dx=1, dy=0, ksize=kernel_size)
    sobel_y = cv2.Sobel(img, cv2.CV_64F, dx=0, dy=1, ksize=kernel_size)

    sobel_x = np.absolute(sobel_x).astype(np.uint8)
    sobel_y = np.absolute(sobel_y).astype(np.uint8)
    return cv2.addWeighted(sobel_x, 0.5, sobel_y, 0.5, 0)

# %%
print("Assignment 1")


 # Define directories of images
input_dir = "../input"
output_dir = "../output"

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

#  Load and resize images
print("\n Loading and resizing images ")
resized_images = load_and_resize_images(input_dir)
print(f"Loaded {len(resized_images)} images")

# Find similar groups based on histograms
print("\n Finding similar image groups ")
# "btc" "chi" "my_chi" ("my_btc" NYI)
groups = find_similar_groups(resized_images, "btc", threshold=0.3)
print(f"Found {len(groups)} similar groups")

# Saving similar groups
print("\n Saving similar groups ")
save_similar_groups(groups, output_dir)

# Processing similar folders
print("\n Processing similar folders...")
process_similar_folders(output_dir)
# Out:
# Assignment 1
#
#  Loading and resizing images
# Loaded and resized: 100000.jpg (979x1305 -> 512x682)
# Loaded and resized: 100001.jpg (979x1305 -> 512x682)
# Loaded and resized: 100002.jpg (1305x979 -> 682x512)
# Loaded and resized: 100100.jpg (1305x979 -> 682x512)
# Loaded and resized: 100101.jpg (1305x979 -> 682x512)
# Loaded and resized: 100200.jpg (979x1305 -> 512x682)
# Loaded and resized: 100201.jpg (1305x979 -> 682x512)
# Loaded and resized: 100300.jpg (979x1305 -> 512x682)
# Loaded and resized: 100301.jpg (1305x979 -> 682x512)
# Loaded and resized: 100302.jpg (1305x979 -> 682x512)
# Loaded and resized: 100400.jpg (979x1305 -> 512x682)
# Loaded and resized: 100401.jpg (339x192 -> 904x512)
# Loaded and resized: 100500.jpg (1305x979 -> 682x512)
# Loaded and resized: 100501.jpg (1305x979 -> 682x512)
# Loaded and resized: 100502.jpg (979x1305 -> 512x682)
# Loaded and resized: 100503.jpg (1305x979 -> 682x512)
# Loaded and resized: 100600.jpg (979x1305 -> 512x682)
# Loaded and resized: 100601.jpg (729x978 -> 512x686)
# Loaded and resized: 100700.jpg (979x1305 -> 512x682)
# Loaded and resized: 100701.jpg (1305x979 -> 682x512)
# Loaded and resized: 100800.jpg (736x1305 -> 512x907)
# Loaded and resized: 100801.jpg (979x1305 -> 512x682)
# Loaded and resized: 100900.jpg (979x1305 -> 512x682)
# Loaded and resized: 100901.jpg (979x1305 -> 512x682)
# Loaded and resized: 100902.jpg (979x1305 -> 512x682)
# Loaded and resized: 101000.jpg (979x1305 -> 512x682)
# Loaded and resized: 101001.jpg (979x1305 -> 512x682)
# Loaded and resized: 101100.jpg (979x1305 -> 512x682)
# Loaded and resized: 101101.jpg (1305x979 -> 682x512)
# Loaded and resized: 101200.jpg (640x480 -> 682x512)
# Loaded and resized: 101201.jpg (640x480 -> 682x512)
# Loaded and resized: 101300.jpg (1024x768 -> 682x512)
# Loaded and resized: 101301.jpg (768x1024 -> 512x682)
# Loaded and resized: 101400.jpg (819x614 -> 682x512)
# Loaded and resized: 101401.jpg (614x819 -> 512x682)
# Loaded and resized: 101402.jpg (819x614 -> 682x512)
# Loaded and resized: 101403.jpg (819x614 -> 682x512)
# Loaded and resized: 101404.jpg (819x614 -> 682x512)
# Loaded and resized: 101500.jpg (819x614 -> 682x512)
# Loaded and resized: 101501.jpg (614x819 -> 512x682)
# Loaded and resized: 101502.jpg (819x614 -> 682x512)
# Loaded and resized: 101503.jpg (819x614 -> 682x512)
# Loaded and resized: 101504.jpg (819x614 -> 682x512)
# Loaded and resized: 101600.jpg (819x614 -> 682x512)
# Loaded and resized: 101601.jpg (819x614 -> 682x512)
# Loaded and resized: 101700.jpg (614x819 -> 512x682)
# Loaded and resized: 101701.jpg (614x819 -> 512x682)
# Loaded and resized: 101702.jpg (614x819 -> 512x682)
# Loaded and resized: 101800.jpg (819x614 -> 682x512)
# Loaded and resized: 101801.jpg (819x614 -> 682x512)
# Loaded and resized: 101900.jpg (819x614 -> 682x512)
# Loaded and resized: 101901.jpg (614x819 -> 512x682)
# Loaded and resized: 102000.jpg (614x819 -> 512x682)
# Loaded and resized: 102001.jpg (614x819 -> 512x682)
# Loaded and resized: 102100.jpg (614x819 -> 512x682)
# Loaded and resized: 102101.jpg (614x819 -> 512x682)
# Loaded and resized: 102200.jpg (844x1126 -> 512x683)
# Loaded and resized: 102201.jpg (614x819 -> 512x682)
# Loaded and resized: 102202.jpg (1126x844 -> 683x512)
# Loaded and resized: 102300.jpg (819x614 -> 682x512)
# Loaded and resized: 102301.jpg (614x819 -> 512x682)
# Loaded and resized: 102302.jpg (819x614 -> 682x512)
# Loaded and resized: 102303.jpg (614x819 -> 512x682)
# Loaded and resized: 102400.jpg (819x614 -> 682x512)
# Loaded and resized: 102401.jpg (819x614 -> 682x512)
# Loaded and resized: 102402.jpg (614x819 -> 512x682)
# Loaded and resized: 102500.jpg (819x614 -> 682x512)
# Loaded and resized: 102501.jpg (819x614 -> 682x512)
# Loaded and resized: 102600.jpg (614x819 -> 512x682)
# Loaded and resized: 102601.jpg (819x614 -> 682x512)
# Loaded and resized: 102700.jpg (819x614 -> 682x512)
# Loaded and resized: 102701.jpg (614x819 -> 512x682)
# Loaded and resized: 102800.jpg (614x819 -> 512x682)
# Loaded and resized: 102801.jpg (819x614 -> 682x512)
# Loaded and resized: 102802.jpg (819x614 -> 682x512)
# Loaded and resized: 102900.jpg (614x819 -> 512x682)
# Loaded and resized: 102901.jpg (819x614 -> 682x512)
# Loaded and resized: 103000.jpg (614x819 -> 512x682)
# Loaded and resized: 103001.jpg (819x614 -> 682x512)
# Loaded and resized: 103002.jpg (614x819 -> 512x682)
# Loaded and resized: 103100.jpg (819x614 -> 682x512)
# Loaded and resized: 103101.jpg (819x614 -> 682x512)
# Loaded and resized: 103102.jpg (819x614 -> 682x512)
# Loaded and resized: 103200.jpg (844x1126 -> 512x683)
# Loaded and resized: 103201.jpg (844x1126 -> 512x683)
# Loaded and resized: 103202.jpg (844x1126 -> 512x683)
# Loaded and resized: 103203.jpg (1126x844 -> 683x512)
# Loaded and resized: 103204.jpg (1126x844 -> 683x512)
# Loaded and resized: 103300.jpg (819x614 -> 682x512)
# Loaded and resized: 103301.jpg (819x614 -> 682x512)
# Loaded and resized: 103302.jpg (614x819 -> 512x682)
# Loaded and resized: 103303.jpg (819x614 -> 682x512)
# Loaded and resized: 103304.jpg (819x614 -> 682x512)
# Loaded and resized: 103400.jpg (819x614 -> 682x512)
# Loaded and resized: 103401.jpg (819x614 -> 682x512)
# Loaded and resized: 103500.jpg (819x614 -> 682x512)
# Loaded and resized: 103501.jpg (819x614 -> 682x512)
# Loaded and resized: 103502.jpg (819x614 -> 682x512)
# Loaded and resized: 103503.jpg (819x614 -> 682x512)
# Loaded and resized: 103600.jpg (819x614 -> 682x512)
# Loaded and resized: 103601.jpg (614x819 -> 512x682)
# Loaded and resized: 103700.jpg (819x614 -> 682x512)
# Loaded and resized: 103701.jpg (614x819 -> 512x682)
# Loaded and resized: 103702.jpg (614x819 -> 512x682)
# Loaded and resized: 103800.jpg (819x614 -> 682x512)
# Loaded and resized: 103801.jpg (819x614 -> 682x512)
# Loaded and resized: 103900.jpg (819x614 -> 682x512)
# Loaded and resized: 103901.jpg (819x614 -> 682x512)
# Loaded and resized: 103902.jpg (819x614 -> 682x512)
# Loaded and resized: 104000.jpg (819x614 -> 682x512)
# Loaded and resized: 104001.jpg (819x614 -> 682x512)
# Loaded and resized: 104002.jpg (819x614 -> 682x512)
# Loaded and resized: 104003.jpg (819x614 -> 682x512)
# Loaded and resized: 104004.jpg (819x614 -> 682x512)
# Loaded and resized: 104005.jpg (819x614 -> 682x512)
# Loaded and resized: 104006.jpg (819x614 -> 682x512)
# Loaded and resized: 104100.jpg (819x614 -> 682x512)
# Loaded and resized: 104101.jpg (819x614 -> 682x512)
# Loaded and resized: 104200.jpg (614x819 -> 512x682)
# Loaded and resized: 104201.jpg (819x614 -> 682x512)
# Loaded and resized: 104202.jpg (819x614 -> 682x512)
# Loaded and resized: 104203.jpg (819x614 -> 682x512)
# Loaded and resized: 104300.jpg (614x819 -> 512x682)
# Loaded and resized: 104301.jpg (614x819 -> 512x682)
# Loaded and resized: 104400.jpg (819x614 -> 682x512)
# Loaded and resized: 104401.jpg (819x614 -> 682x512)
# Loaded and resized: 104402.jpg (819x614 -> 682x512)
# Loaded and resized: 104500.jpg (819x614 -> 682x512)
# Loaded and resized: 104501.jpg (819x614 -> 682x512)
# Loaded and resized: 104502.jpg (819x614 -> 682x512)
# Loaded and resized: 104600.jpg (819x614 -> 682x512)
# Loaded and resized: 104601.jpg (819x614 -> 682x512)
# Loaded and resized: 104700.jpg (614x819 -> 512x682)
# Loaded and resized: 104701.jpg (614x819 -> 512x682)
# Loaded and resized: 104800.jpg (819x614 -> 682x512)
# Loaded and resized: 104801.jpg (819x614 -> 682x512)
# Loaded and resized: 104802.jpg (819x614 -> 682x512)
# Loaded and resized: 104900.jpg (819x614 -> 682x512)
# Loaded and resized: 104901.jpg (614x819 -> 512x682)
# Loaded and resized: 104902.jpg (614x819 -> 512x682)
# Loaded and resized: 105000.jpg (819x614 -> 682x512)
# Loaded and resized: 105001.jpg (819x614 -> 682x512)
# Loaded and resized: 105002.jpg (819x614 -> 682x512)
# Loaded and resized: 105100.jpg (819x614 -> 682x512)
# Loaded and resized: 105101.jpg (614x819 -> 512x682)
# Loaded and resized: 105102.jpg (819x614 -> 682x512)
# Loaded and resized: 105103.jpg (614x819 -> 512x682)
# Loaded and resized: 105104.jpg (819x614 -> 682x512)
# Loaded and resized: 105200.jpg (614x819 -> 512x682)
# Loaded and resized: 105201.jpg (614x819 -> 512x682)
# Loaded and resized: 105300.jpg (614x819 -> 512x682)
# Loaded and resized: 105301.jpg (819x614 -> 682x512)
# Loaded and resized: 105400.jpg (614x819 -> 512x682)
# Loaded and resized: 105401.jpg (614x819 -> 512x682)
# Loaded and resized: 105500.jpg (819x614 -> 682x512)
# Loaded and resized: 105501.jpg (819x614 -> 682x512)
# Loaded and resized: 105600.jpg (819x614 -> 682x512)
# Loaded and resized: 105601.jpg (819x614 -> 682x512)
# Loaded and resized: 105700.jpg (614x819 -> 512x682)
# Loaded and resized: 105701.jpg (614x819 -> 512x682)
# Loaded and resized: 105800.jpg (1126x844 -> 683x512)
# Loaded and resized: 105801.jpg (1126x844 -> 683x512)
# Loaded and resized: 105802.jpg (1126x844 -> 683x512)
# Loaded and resized: 105900.jpg (819x614 -> 682x512)
# Loaded and resized: 105901.jpg (819x614 -> 682x512)
# Loaded and resized: 106000.jpg (614x819 -> 512x682)
# Loaded and resized: 106001.jpg (819x614 -> 682x512)
# Loaded and resized: 106002.jpg (614x819 -> 512x682)
# Loaded and resized: 106100.jpg (614x819 -> 512x682)
# Loaded and resized: 106101.jpg (614x819 -> 512x682)
# Loaded and resized: 106200.jpg (819x614 -> 682x512)
# Loaded and resized: 106201.jpg (819x614 -> 682x512)
# Loaded and resized: 106202.jpg (819x614 -> 682x512)
# Loaded and resized: 106300.jpg (1305x979 -> 682x512)
# Loaded and resized: 106301.jpg (979x1305 -> 512x682)
# Loaded and resized: 106400.jpg (1305x979 -> 682x512)
# Loaded and resized: 106401.jpg (1305x979 -> 682x512)
# Loaded and resized: 106402.jpg (979x1305 -> 512x682)
# Loaded and resized: 106403.jpg (1305x979 -> 682x512)
# Loaded and resized: 106500.jpg (979x1305 -> 512x682)
# Loaded and resized: 106501.jpg (979x1305 -> 512x682)
# Loaded and resized: 106600.jpg (1305x979 -> 682x512)
# Loaded and resized: 106601.jpg (979x1305 -> 512x682)
# Loaded and resized: 106602.jpg (1305x979 -> 682x512)
# Loaded and resized: 106603.jpg (979x1305 -> 512x682)
# Loaded and resized: 106604.jpg (979x1305 -> 512x682)
# Loaded and resized: 106605.jpg (1305x979 -> 682x512)
# Loaded and resized: 106606.jpg (1305x736 -> 907x512)
# Loaded and resized: 106700.jpg (339x192 -> 904x512)
# Loaded and resized: 106701.jpg (979x1305 -> 512x682)
# Loaded and resized: 106702.jpg (1024x768 -> 682x512)
# Loaded and resized: 106703.jpg (979x1305 -> 512x682)
# Loaded and resized: 106704.jpg (1305x979 -> 682x512)
# Loaded and resized: 106800.jpg (768x1024 -> 512x682)
# Loaded and resized: 106801.jpg (1024x768 -> 682x512)
# Loaded and resized: 106900.jpg (768x1024 -> 512x682)
# Loaded and resized: 106901.jpg (768x1024 -> 512x682)
# Loaded and resized: 106902.jpg (768x1024 -> 512x682)
# Loaded and resized: 106903.jpg (768x1024 -> 512x682)
# Loaded and resized: 107000.jpg (1305x979 -> 682x512)
# Loaded and resized: 107001.jpg (339x192 -> 904x512)
# Loaded and resized: 107100.jpg (1305x979 -> 682x512)
# Loaded and resized: 107101.jpg (1305x979 -> 682x512)
# Loaded and resized: 107200.jpg (1305x979 -> 682x512)
# Loaded and resized: 107201.jpg (979x1305 -> 512x682)
# Loaded and resized: 107202.jpg (1305x979 -> 682x512)
# Loaded and resized: 107203.jpg (979x1305 -> 512x682)
# Loaded and resized: 107300.jpg (1305x979 -> 682x512)
# Loaded and resized: 107301.jpg (979x1305 -> 512x682)
# Loaded and resized: 107400.jpg (979x1305 -> 512x682)
# Loaded and resized: 107401.jpg (979x1305 -> 512x682)
# Loaded and resized: 107500.jpg (979x1305 -> 512x682)
# Loaded and resized: 107501.jpg (979x1305 -> 512x682)
# Loaded and resized: 107600.jpg (1305x979 -> 682x512)
# Loaded and resized: 107601.jpg (1305x979 -> 682x512)
# Loaded and resized: 107700.jpg (768x1024 -> 512x682)
# Loaded and resized: 107701.jpg (1305x979 -> 682x512)
# Loaded and resized: 107702.jpg (979x1305 -> 512x682)
# Loaded and resized: 107800.jpg (1305x979 -> 682x512)
# Loaded and resized: 107801.jpg (979x1305 -> 512x682)
# Loaded and resized: 107900.jpg (979x1305 -> 512x682)
# Loaded and resized: 107901.jpg (1305x979 -> 682x512)
# Loaded and resized: 107902.jpg (1305x979 -> 682x512)
# Loaded and resized: 108000.jpg (819x614 -> 682x512)
# Loaded and resized: 108001.jpg (819x614 -> 682x512)
# Loaded and resized: 108100.jpg (1024x768 -> 682x512)
# Loaded and resized: 108101.jpg (1024x768 -> 682x512)
# Loaded and resized: 108102.jpg (1024x768 -> 682x512)
# Loaded and resized: 108103.jpg (1024x768 -> 682x512)
# Loaded and resized: 108104.jpg (1024x768 -> 682x512)
# Loaded and resized: 108105.jpg (1024x768 -> 682x512)
# Loaded and resized: 108106.jpg (1024x768 -> 682x512)
# Loaded and resized: 108200.jpg (1024x768 -> 682x512)
# Loaded and resized: 108201.jpg (1024x768 -> 682x512)
# Loaded and resized: 108202.jpg (1024x768 -> 682x512)
# Loaded and resized: 108203.jpg (1024x768 -> 682x512)
# Loaded and resized: 108300.jpg (1024x768 -> 682x512)
# Loaded and resized: 108301.jpg (1024x768 -> 682x512)
# Loaded and resized: 108400.jpg (1024x768 -> 682x512)
# Loaded and resized: 108401.jpg (1024x768 -> 682x512)
# Loaded and resized: 108500.jpg (1024x768 -> 682x512)
# Loaded and resized: 108501.jpg (1024x768 -> 682x512)
# Loaded and resized: 108600.jpg (768x1024 -> 512x682)
# Loaded and resized: 108601.jpg (1024x768 -> 682x512)
# Loaded and resized: 108700.jpg (768x1024 -> 512x682)
# Loaded and resized: 108701.jpg (768x1024 -> 512x682)
# Loaded and resized: 108800.jpg (1024x768 -> 682x512)
# Loaded and resized: 108801.jpg (1024x768 -> 682x512)
# Loaded and resized: 108802.jpg (1024x768 -> 682x512)
# Loaded and resized: 108900.jpg (640x480 -> 682x512)
# Loaded and resized: 108901.jpg (640x480 -> 682x512)
# Loaded and resized: 108902.jpg (640x480 -> 682x512)
# Loaded and resized: 109000.jpg (640x480 -> 682x512)
# Loaded and resized: 109001.jpg (480x640 -> 512x682)
# Loaded and resized: 109100.jpg (640x480 -> 682x512)
# Loaded and resized: 109101.jpg (480x640 -> 512x682)
# Loaded and resized: 109200.jpg (480x640 -> 512x682)
# Loaded and resized: 109201.jpg (480x640 -> 512x682)
# Loaded and resized: 109300.jpg (614x819 -> 512x682)
# Loaded and resized: 109301.jpg (819x614 -> 682x512)
# Loaded and resized: 109400.jpg (819x614 -> 682x512)
# Loaded and resized: 109401.jpg (819x614 -> 682x512)
# Loaded and resized: 109402.jpg (819x614 -> 682x512)
# Loaded and resized: 109500.jpg (819x614 -> 682x512)
# Loaded and resized: 109501.jpg (819x614 -> 682x512)
# Loaded and resized: 109600.jpg (819x614 -> 682x512)
# Loaded and resized: 109601.jpg (819x614 -> 682x512)
# Loaded and resized: 109700.jpg (819x614 -> 682x512)
# Loaded and resized: 109701.jpg (819x614 -> 682x512)
# Loaded and resized: 109800.jpg (819x614 -> 682x512)
# Loaded and resized: 109801.jpg (819x614 -> 682x512)
# Loaded and resized: 109802.jpg (819x614 -> 682x512)
# Loaded and resized: 109900.jpg (480x640 -> 512x682)
# Loaded and resized: 109901.jpg (480x640 -> 512x682)
# Loaded 274 images
#
#  Finding similar image groups
# Distance between image 100000.jpg and image 100001.jpg: 0.2664
# Distance between image 100001.jpg and image 100002.jpg: 0.6063
# Distance between image 100002.jpg and image 100100.jpg: 0.4366
# Distance between image 100100.jpg and image 100101.jpg: 0.4300
# Distance between image 100101.jpg and image 100200.jpg: 0.5800
# Distance between image 100200.jpg and image 100201.jpg: 0.4855
# Distance between image 100201.jpg and image 100300.jpg: 0.6723
# Distance between image 100300.jpg and image 100301.jpg: 0.3448
# Distance between image 100301.jpg and image 100302.jpg: 0.1580
# Distance between image 100302.jpg and image 100400.jpg: 0.3238
# Distance between image 100400.jpg and image 100401.jpg: 0.5511
# Distance between image 100401.jpg and image 100500.jpg: 0.8494
# Distance between image 100500.jpg and image 100501.jpg: 0.5058
# Distance between image 100501.jpg and image 100502.jpg: 0.3037
# Distance between image 100502.jpg and image 100503.jpg: 0.3109
# Distance between image 100503.jpg and image 100600.jpg: 0.7693
# Distance between image 100600.jpg and image 100601.jpg: 0.3923
# Distance between image 100601.jpg and image 100700.jpg: 0.5594
# Distance between image 100700.jpg and image 100701.jpg: 0.3621
# Distance between image 100701.jpg and image 100800.jpg: 0.8126
# Distance between image 100800.jpg and image 100801.jpg: 0.3019
# Distance between image 100801.jpg and image 100900.jpg: 0.7170
# Distance between image 100900.jpg and image 100901.jpg: 0.5591
# Distance between image 100901.jpg and image 100902.jpg: 0.3064
# Distance between image 100902.jpg and image 101000.jpg: 0.6470
# Distance between image 101000.jpg and image 101001.jpg: 0.3220
# Distance between image 101001.jpg and image 101100.jpg: 0.5243
# Distance between image 101100.jpg and image 101101.jpg: 0.2505
# Distance between image 101101.jpg and image 101200.jpg: 0.7901
# Distance between image 101200.jpg and image 101201.jpg: 0.5180
# Distance between image 101201.jpg and image 101300.jpg: 0.8512
# Distance between image 101300.jpg and image 101301.jpg: 0.3246
# Distance between image 101301.jpg and image 101400.jpg: 0.8548
# Distance between image 101400.jpg and image 101401.jpg: 0.5167
# Distance between image 101401.jpg and image 101402.jpg: 0.5596
# Distance between image 101402.jpg and image 101403.jpg: 0.3572
# Distance between image 101403.jpg and image 101404.jpg: 0.6602
# Distance between image 101404.jpg and image 101500.jpg: 0.9070
# Distance between image 101500.jpg and image 101501.jpg: 0.3063
# Distance between image 101501.jpg and image 101502.jpg: 0.7040
# Distance between image 101502.jpg and image 101503.jpg: 0.5057
# Distance between image 101503.jpg and image 101504.jpg: 0.5387
# Distance between image 101504.jpg and image 101600.jpg: 0.7500
# Distance between image 101600.jpg and image 101601.jpg: 0.1126
# Distance between image 101601.jpg and image 101700.jpg: 0.9108
# Distance between image 101700.jpg and image 101701.jpg: 0.1783
# Distance between image 101701.jpg and image 101702.jpg: 0.5862
# Distance between image 101702.jpg and image 101800.jpg: 0.9638
# Distance between image 101800.jpg and image 101801.jpg: 0.7793
# Distance between image 101801.jpg and image 101900.jpg: 0.9199
# Distance between image 101900.jpg and image 101901.jpg: 0.2189
# Distance between image 101901.jpg and image 102000.jpg: 0.7783
# Distance between image 102000.jpg and image 102001.jpg: 0.2896
# Distance between image 102001.jpg and image 102100.jpg: 0.9581
# Distance between image 102100.jpg and image 102101.jpg: 0.7219
# Distance between image 102101.jpg and image 102200.jpg: 0.5793
# Distance between image 102200.jpg and image 102201.jpg: 0.4648
# Distance between image 102201.jpg and image 102202.jpg: 0.5036
# Distance between image 102202.jpg and image 102300.jpg: 0.6863
# Distance between image 102300.jpg and image 102301.jpg: 0.1769
# Distance between image 102301.jpg and image 102302.jpg: 0.3181
# Distance between image 102302.jpg and image 102303.jpg: 0.2521
# Distance between image 102303.jpg and image 102400.jpg: 0.5202
# Distance between image 102400.jpg and image 102401.jpg: 0.3668
# Distance between image 102401.jpg and image 102402.jpg: 0.3223
# Distance between image 102402.jpg and image 102500.jpg: 0.5225
# Distance between image 102500.jpg and image 102501.jpg: 0.2013
# Distance between image 102501.jpg and image 102600.jpg: 0.3670
# Distance between image 102600.jpg and image 102601.jpg: 0.1327
# Distance between image 102601.jpg and image 102700.jpg: 0.6335
# Distance between image 102700.jpg and image 102701.jpg: 0.4787
# Distance between image 102701.jpg and image 102800.jpg: 0.6713
# Distance between image 102800.jpg and image 102801.jpg: 0.4769
# Distance between image 102801.jpg and image 102802.jpg: 0.3573
# Distance between image 102802.jpg and image 102900.jpg: 0.6966
# Distance between image 102900.jpg and image 102901.jpg: 0.3900
# Distance between image 102901.jpg and image 103000.jpg: 0.7390
# Distance between image 103000.jpg and image 103001.jpg: 0.6631
# Distance between image 103001.jpg and image 103002.jpg: 0.5263
# Distance between image 103002.jpg and image 103100.jpg: 0.8707
# Distance between image 103100.jpg and image 103101.jpg: 0.2397
# Distance between image 103101.jpg and image 103102.jpg: 0.2419
# Distance between image 103102.jpg and image 103200.jpg: 0.7832
# Distance between image 103200.jpg and image 103201.jpg: 0.3537
# Distance between image 103201.jpg and image 103202.jpg: 0.5524
# Distance between image 103202.jpg and image 103203.jpg: 0.3899
# Distance between image 103203.jpg and image 103204.jpg: 0.5217
# Distance between image 103204.jpg and image 103300.jpg: 0.6951
# Distance between image 103300.jpg and image 103301.jpg: 0.5349
# Distance between image 103301.jpg and image 103302.jpg: 0.5461
# Distance between image 103302.jpg and image 103303.jpg: 0.5191
# Distance between image 103303.jpg and image 103304.jpg: 0.3510
# Distance between image 103304.jpg and image 103400.jpg: 0.8421
# Distance between image 103400.jpg and image 103401.jpg: 0.1954
# Distance between image 103401.jpg and image 103500.jpg: 0.6284
# Distance between image 103500.jpg and image 103501.jpg: 0.1644
# Distance between image 103501.jpg and image 103502.jpg: 0.1826
# Distance between image 103502.jpg and image 103503.jpg: 0.1766
# Distance between image 103503.jpg and image 103600.jpg: 0.5984
# Distance between image 103600.jpg and image 103601.jpg: 0.1917
# Distance between image 103601.jpg and image 103700.jpg: 0.4441
# Distance between image 103700.jpg and image 103701.jpg: 0.2190
# Distance between image 103701.jpg and image 103702.jpg: 0.1425
# Distance between image 103702.jpg and image 103800.jpg: 0.3309
# Distance between image 103800.jpg and image 103801.jpg: 0.6312
# Distance between image 103801.jpg and image 103900.jpg: 0.6286
# Distance between image 103900.jpg and image 103901.jpg: 0.2397
# Distance between image 103901.jpg and image 103902.jpg: 0.2419
# Distance between image 103902.jpg and image 104000.jpg: 0.5302
# Distance between image 104000.jpg and image 104001.jpg: 0.0461
# Distance between image 104001.jpg and image 104002.jpg: 0.0292
# Distance between image 104002.jpg and image 104003.jpg: 0.2304
# Distance between image 104003.jpg and image 104004.jpg: 0.0397
# Distance between image 104004.jpg and image 104005.jpg: 0.1457
# Distance between image 104005.jpg and image 104006.jpg: 0.1417
# Distance between image 104006.jpg and image 104100.jpg: 0.3417
# Distance between image 104100.jpg and image 104101.jpg: 0.1739
# Distance between image 104101.jpg and image 104200.jpg: 0.8964
# Distance between image 104200.jpg and image 104201.jpg: 0.6883
# Distance between image 104201.jpg and image 104202.jpg: 0.9421
# Distance between image 104202.jpg and image 104203.jpg: 0.7873
# Distance between image 104203.jpg and image 104300.jpg: 0.6884
# Distance between image 104300.jpg and image 104301.jpg: 0.3361
# Distance between image 104301.jpg and image 104400.jpg: 0.5837
# Distance between image 104400.jpg and image 104401.jpg: 0.4253
# Distance between image 104401.jpg and image 104402.jpg: 0.5305
# Distance between image 104402.jpg and image 104500.jpg: 0.4437
# Distance between image 104500.jpg and image 104501.jpg: 0.3274
# Distance between image 104501.jpg and image 104502.jpg: 0.1580
# Distance between image 104502.jpg and image 104600.jpg: 0.5178
# Distance between image 104600.jpg and image 104601.jpg: 0.6282
# Distance between image 104601.jpg and image 104700.jpg: 0.4306
# Distance between image 104700.jpg and image 104701.jpg: 0.2486
# Distance between image 104701.jpg and image 104800.jpg: 0.4657
# Distance between image 104800.jpg and image 104801.jpg: 0.4168
# Distance between image 104801.jpg and image 104802.jpg: 0.6409
# Distance between image 104802.jpg and image 104900.jpg: 0.7195
# Distance between image 104900.jpg and image 104901.jpg: 0.1820
# Distance between image 104901.jpg and image 104902.jpg: 0.0553
# Distance between image 104902.jpg and image 105000.jpg: 0.4185
# Distance between image 105000.jpg and image 105001.jpg: 0.3348
# Distance between image 105001.jpg and image 105002.jpg: 0.4809
# Distance between image 105002.jpg and image 105100.jpg: 0.5445
# Distance between image 105100.jpg and image 105101.jpg: 0.3198
# Distance between image 105101.jpg and image 105102.jpg: 0.3536
# Distance between image 105102.jpg and image 105103.jpg: 0.3986
# Distance between image 105103.jpg and image 105104.jpg: 0.1975
# Distance between image 105104.jpg and image 105200.jpg: 0.5208
# Distance between image 105200.jpg and image 105201.jpg: 0.5161
# Distance between image 105201.jpg and image 105300.jpg: 0.4288
# Distance between image 105300.jpg and image 105301.jpg: 0.5278
# Distance between image 105301.jpg and image 105400.jpg: 0.5508
# Distance between image 105400.jpg and image 105401.jpg: 0.5086
# Distance between image 105401.jpg and image 105500.jpg: 0.2790
# Distance between image 105500.jpg and image 105501.jpg: 0.2745
# Distance between image 105501.jpg and image 105600.jpg: 0.4929
# Distance between image 105600.jpg and image 105601.jpg: 0.1186
# Distance between image 105601.jpg and image 105700.jpg: 0.7938
# Distance between image 105700.jpg and image 105701.jpg: 0.4638
# Distance between image 105701.jpg and image 105800.jpg: 0.8681
# Distance between image 105800.jpg and image 105801.jpg: 0.7924
# Distance between image 105801.jpg and image 105802.jpg: 0.6328
# Distance between image 105802.jpg and image 105900.jpg: 0.7189
# Distance between image 105900.jpg and image 105901.jpg: 0.3051
# Distance between image 105901.jpg and image 106000.jpg: 0.2728
# Distance between image 106000.jpg and image 106001.jpg: 0.8267
# Distance between image 106001.jpg and image 106002.jpg: 0.7634
# Distance between image 106002.jpg and image 106100.jpg: 0.4593
# Distance between image 106100.jpg and image 106101.jpg: 0.4438
# Distance between image 106101.jpg and image 106200.jpg: 0.7408
# Distance between image 106200.jpg and image 106201.jpg: 0.0598
# Distance between image 106201.jpg and image 106202.jpg: 0.1202
# Distance between image 106202.jpg and image 106300.jpg: 0.7297
# Distance between image 106300.jpg and image 106301.jpg: 0.3442
# Distance between image 106301.jpg and image 106400.jpg: 0.7650
# Distance between image 106400.jpg and image 106401.jpg: 0.7851
# Distance between image 106401.jpg and image 106402.jpg: 0.7259
# Distance between image 106402.jpg and image 106403.jpg: 0.6217
# Distance between image 106403.jpg and image 106500.jpg: 0.8754
# Distance between image 106500.jpg and image 106501.jpg: 0.1475
# Distance between image 106501.jpg and image 106600.jpg: 0.5840
# Distance between image 106600.jpg and image 106601.jpg: 0.1446
# Distance between image 106601.jpg and image 106602.jpg: 0.2578
# Distance between image 106602.jpg and image 106603.jpg: 0.2552
# Distance between image 106603.jpg and image 106604.jpg: 0.1097
# Distance between image 106604.jpg and image 106605.jpg: 0.3873
# Distance between image 106605.jpg and image 106606.jpg: 0.1614
# Distance between image 106606.jpg and image 106700.jpg: 0.6629
# Distance between image 106700.jpg and image 106701.jpg: 0.6869
# Distance between image 106701.jpg and image 106702.jpg: 0.2450
# Distance between image 106702.jpg and image 106703.jpg: 0.4836
# Distance between image 106703.jpg and image 106704.jpg: 0.1739
# Distance between image 106704.jpg and image 106800.jpg: 0.7239
# Distance between image 106800.jpg and image 106801.jpg: 0.1837
# Distance between image 106801.jpg and image 106900.jpg: 0.4588
# Distance between image 106900.jpg and image 106901.jpg: 0.0840
# Distance between image 106901.jpg and image 106902.jpg: 0.1676
# Distance between image 106902.jpg and image 106903.jpg: 0.4502
# Distance between image 106903.jpg and image 107000.jpg: 0.6011
# Distance between image 107000.jpg and image 107001.jpg: 0.9612
# Distance between image 107001.jpg and image 107100.jpg: 0.9879
# Distance between image 107100.jpg and image 107101.jpg: 0.1158
# Distance between image 107101.jpg and image 107200.jpg: 0.5786
# Distance between image 107200.jpg and image 107201.jpg: 0.1741
# Distance between image 107201.jpg and image 107202.jpg: 0.2157
# Distance between image 107202.jpg and image 107203.jpg: 0.3292
# Distance between image 107203.jpg and image 107300.jpg: 0.5860
# Distance between image 107300.jpg and image 107301.jpg: 0.2816
# Distance between image 107301.jpg and image 107400.jpg: 0.7011
# Distance between image 107400.jpg and image 107401.jpg: 0.0804
# Distance between image 107401.jpg and image 107500.jpg: 0.5075
# Distance between image 107500.jpg and image 107501.jpg: 0.5883
# Distance between image 107501.jpg and image 107600.jpg: 0.3391
# Distance between image 107600.jpg and image 107601.jpg: 0.1573
# Distance between image 107601.jpg and image 107700.jpg: 0.7760
# Distance between image 107700.jpg and image 107701.jpg: 0.4162
# Distance between image 107701.jpg and image 107702.jpg: 0.4678
# Distance between image 107702.jpg and image 107800.jpg: 0.5884
# Distance between image 107800.jpg and image 107801.jpg: 0.1451
# Distance between image 107801.jpg and image 107900.jpg: 0.5280
# Distance between image 107900.jpg and image 107901.jpg: 0.2803
# Distance between image 107901.jpg and image 107902.jpg: 0.5080
# Distance between image 107902.jpg and image 108000.jpg: 0.7235
# Distance between image 108000.jpg and image 108001.jpg: 0.7187
# Distance between image 108001.jpg and image 108100.jpg: 0.8498
# Distance between image 108100.jpg and image 108101.jpg: 0.1508
# Distance between image 108101.jpg and image 108102.jpg: 0.4522
# Distance between image 108102.jpg and image 108103.jpg: 0.1861
# Distance between image 108103.jpg and image 108104.jpg: 0.6552
# Distance between image 108104.jpg and image 108105.jpg: 0.3087
# Distance between image 108105.jpg and image 108106.jpg: 0.9129
# Distance between image 108106.jpg and image 108200.jpg: 0.9972
# Distance between image 108200.jpg and image 108201.jpg: 0.3484
# Distance between image 108201.jpg and image 108202.jpg: 0.3422
# Distance between image 108202.jpg and image 108203.jpg: 0.6036
# Distance between image 108203.jpg and image 108300.jpg: 0.8494
# Distance between image 108300.jpg and image 108301.jpg: 0.4391
# Distance between image 108301.jpg and image 108400.jpg: 0.5901
# Distance between image 108400.jpg and image 108401.jpg: 0.5409
# Distance between image 108401.jpg and image 108500.jpg: 0.8021
# Distance between image 108500.jpg and image 108501.jpg: 0.2945
# Distance between image 108501.jpg and image 108600.jpg: 0.7040
# Distance between image 108600.jpg and image 108601.jpg: 0.5267
# Distance between image 108601.jpg and image 108700.jpg: 0.5980
# Distance between image 108700.jpg and image 108701.jpg: 0.1705
# Distance between image 108701.jpg and image 108800.jpg: 0.5755
# Distance between image 108800.jpg and image 108801.jpg: 0.1544
# Distance between image 108801.jpg and image 108802.jpg: 0.6223
# Distance between image 108802.jpg and image 108900.jpg: 0.7028
# Distance between image 108900.jpg and image 108901.jpg: 0.7944
# Distance between image 108901.jpg and image 108902.jpg: 0.2362
# Distance between image 108902.jpg and image 109000.jpg: 0.3744
# Distance between image 109000.jpg and image 109001.jpg: 0.5626
# Distance between image 109001.jpg and image 109100.jpg: 0.8854
# Distance between image 109100.jpg and image 109101.jpg: 0.6196
# Distance between image 109101.jpg and image 109200.jpg: 0.5393
# Distance between image 109200.jpg and image 109201.jpg: 0.4113
# Distance between image 109201.jpg and image 109300.jpg: 0.5733
# Distance between image 109300.jpg and image 109301.jpg: 0.3288
# Distance between image 109301.jpg and image 109400.jpg: 0.5512
# Distance between image 109400.jpg and image 109401.jpg: 0.1657
# Distance between image 109401.jpg and image 109402.jpg: 0.2020
# Distance between image 109402.jpg and image 109500.jpg: 0.6561
# Distance between image 109500.jpg and image 109501.jpg: 0.4989
# Distance between image 109501.jpg and image 109600.jpg: 0.8258
# Distance between image 109600.jpg and image 109601.jpg: 0.3269
# Distance between image 109601.jpg and image 109700.jpg: 0.6856
# Distance between image 109700.jpg and image 109701.jpg: 0.2544
# Distance between image 109701.jpg and image 109800.jpg: 0.6762
# Distance between image 109800.jpg and image 109801.jpg: 0.2019
# Distance between image 109801.jpg and image 109802.jpg: 0.4847
# Distance between image 109802.jpg and image 109900.jpg: 0.9308
# Distance between image 109900.jpg and image 109901.jpg: 0.1025
# Found 12 similar groups
#
#  Saving similar groups
# Created similar-0 with 3 images
# Created similar-1 with 4 images
# Created similar-2 with 3 images
# Created similar-3 with 3 images
# Created similar-4 with 7 images
# Created similar-5 with 3 images
# Created similar-6 with 3 images
# Created similar-7 with 3 images
# Created similar-8 with 5 images
# Created similar-9 with 3 images
# Created similar-10 with 3 images
# Created similar-11 with 3 images
#
#  Processing similar folders...
#
# Processing similar-0...
#   Found 10 images
#   Average color (RGB): [102, 144, 133]
#   Applying white balance to 10 images...
#   Saved histogram visualization: ../output\similar-0\histograms.jpg
#  similar-0 processed successfully
#
# Processing similar-1...
#   Found 7 images
#   Average color (RGB): [97, 133, 123]
#   Applying white balance to 7 images...
#   Saved histogram visualization: ../output\similar-1\histograms.jpg
#  similar-1 processed successfully
#
# Processing similar-10...
#   Found 3 images
#   Average color (RGB): [115, 132, 106]
#   Applying white balance to 3 images...
#   Saved histogram visualization: ../output\similar-10\histograms.jpg
#  similar-10 processed successfully
#
# Processing similar-11...
#   Found 3 images
#   Average color (RGB): [144, 107, 99]
#   Applying white balance to 3 images...
#   Saved histogram visualization: ../output\similar-11\histograms.jpg
#  similar-11 processed successfully
#
# Processing similar-2...
#   Found 7 images
#   Average color (RGB): [114, 136, 121]
#   Applying white balance to 7 images...
#   Saved histogram visualization: ../output\similar-2\histograms.jpg
#  similar-2 processed successfully
#
# Processing similar-3...
#   Found 6 images
#   Average color (RGB): [122, 151, 140]
#   Applying white balance to 6 images...
#   Saved histogram visualization: ../output\similar-3\histograms.jpg
#  similar-3 processed successfully
#
# Processing similar-4...
#   Found 10 images
#   Average color (RGB): [109, 134, 122]
#   Applying white balance to 10 images...
#   Saved histogram visualization: ../output\similar-4\histograms.jpg
#  similar-4 processed successfully
#
# Processing similar-5...
#   Found 3 images
#   Average color (RGB): [137, 133, 131]
#   Applying white balance to 3 images...
#   Saved histogram visualization: ../output\similar-5\histograms.jpg
#  similar-5 processed successfully
#
# Processing similar-6...
#   Found 3 images
#   Average color (RGB): [91, 90, 82]
#   Applying white balance to 3 images...
#   Saved histogram visualization: ../output\similar-6\histograms.jpg
#  similar-6 processed successfully
#
# Processing similar-7...
#   Found 3 images
#   Average color (RGB): [71, 141, 149]
#   Applying white balance to 3 images...
#   Saved histogram visualization: ../output\similar-7\histograms.jpg
#  similar-7 processed successfully
#
# Processing similar-8...
#   Found 5 images
#   Average color (RGB): [111, 111, 113]
#   Applying white balance to 5 images...
#   Saved histogram visualization: ../output\similar-8\histograms.jpg
#  similar-8 processed successfully
#
# Processing similar-9...
#   Found 3 images
#   Average color (RGB): [57, 96, 98]
#   Applying white balance to 3 images...
#   Saved histogram visualization: ../output\similar-9\histograms.jpg
#  similar-9 processed successfully

# %%
import json
with open(f"{input_dir}/groundtruth.json") as file:
    data = json.load(file)

similarities = {}
# print(data["0"][])
for i in data:
    # print(data[i])
    similarities[data[i]["query"]] = data[i]["similar"]

# %%
def check_correctness():
    paths = os.listdir("../output")
    # print(paths)
    for path in paths:
        files = sorted(glob.glob(os.path.join(f"{output_dir}/{path}", "*.*")))
        print(files)

# %%
check_correctness()
# Out:
# ['../output/similar-0\\103100.jpg', '../output/similar-0\\103101.jpg', '../output/similar-0\\103102.jpg', '../output/similar-0\\103500.jpg', '../output/similar-0\\103501.jpg', '../output/similar-0\\103502.jpg', '../output/similar-0\\103503.jpg', '../output/similar-0\\104000.jpg', '../output/similar-0\\104001.jpg', '../output/similar-0\\104002.jpg', '../output/similar-0\\histograms.jpg']
# ['../output/similar-1\\103500.jpg', '../output/similar-1\\103501.jpg', '../output/similar-1\\103502.jpg', '../output/similar-1\\103503.jpg', '../output/similar-1\\104000.jpg', '../output/similar-1\\104001.jpg', '../output/similar-1\\104002.jpg', '../output/similar-1\\histograms.jpg']
# ['../output/similar-10\\107200.jpg', '../output/similar-10\\107201.jpg', '../output/similar-10\\107202.jpg', '../output/similar-10\\histograms.jpg']
# ['../output/similar-11\\109400.jpg', '../output/similar-11\\109401.jpg', '../output/similar-11\\109402.jpg', '../output/similar-11\\histograms.jpg']
# ['../output/similar-2\\103700.jpg', '../output/similar-2\\103701.jpg', '../output/similar-2\\103702.jpg', '../output/similar-2\\104003.jpg', '../output/similar-2\\104004.jpg', '../output/similar-2\\104005.jpg', '../output/similar-2\\104006.jpg', '../output/similar-2\\histograms.jpg']
# ['../output/similar-3\\103900.jpg', '../output/similar-3\\103901.jpg', '../output/similar-3\\103902.jpg', '../output/similar-3\\104900.jpg', '../output/similar-3\\104901.jpg', '../output/similar-3\\104902.jpg', '../output/similar-3\\histograms.jpg']
# ['../output/similar-4\\104000.jpg', '../output/similar-4\\104001.jpg', '../output/similar-4\\104002.jpg', '../output/similar-4\\104003.jpg', '../output/similar-4\\104004.jpg', '../output/similar-4\\104005.jpg', '../output/similar-4\\104006.jpg', '../output/similar-4\\106200.jpg', '../output/similar-4\\106201.jpg', '../output/similar-4\\106202.jpg', '../output/similar-4\\histograms.jpg']
# ['../output/similar-5\\104900.jpg', '../output/similar-5\\104901.jpg', '../output/similar-5\\104902.jpg', '../output/similar-5\\histograms.jpg']
# ['../output/similar-6\\105401.jpg', '../output/similar-6\\105500.jpg', '../output/similar-6\\105501.jpg', '../output/similar-6\\histograms.jpg']
# ['../output/similar-7\\106200.jpg', '../output/similar-7\\106201.jpg', '../output/similar-7\\106202.jpg', '../output/similar-7\\histograms.jpg']
# ['../output/similar-8\\106600.jpg', '../output/similar-8\\106601.jpg', '../output/similar-8\\106602.jpg', '../output/similar-8\\106603.jpg', '../output/similar-8\\106604.jpg', '../output/similar-8\\histograms.jpg']
# ['../output/similar-9\\106900.jpg', '../output/similar-9\\106901.jpg', '../output/similar-9\\106902.jpg', '../output/similar-9\\histograms.jpg']
